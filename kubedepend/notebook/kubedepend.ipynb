# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
results_raw = pd.read_csv('../results/results.csv')
results_raw.head()
# Out:
#                                      id  measurement_seq_start_time  \
# 0  d73e6687-5dde-4630-ac81-cc782cc4182c  04-07-2021_00-04-20.303398
# 1  c1be61c2-580d-4b2d-8aeb-2446c1bed119  04-07-2021_00-28-40.470254
# 2  c1be61c2-580d-4b2d-8aeb-2446c1bed119  04-07-2021_00-28-40.470254
# 3  fb02bd7c-3434-4a65-821f-e527270cee19  04-07-2021_09-40-34.423576
# 4  fb02bd7c-3434-4a65-821f-e527270cee19  04-07-2021_09-40-34.423576
#
#    availability     mut    mdt    mtbf      measurement_start_time  \
# 0      0.135135   18.75  160.0  178.75  04-07-2021_00-04-31.643939
# 1      1.000000  600.00    NaN     NaN  04-07-2021_00-28-48.925095
# 2      0.900000  135.00   20.0  155.00  04-07-2021_00-45-03.390138
# 3      0.475000   57.00   60.0  117.00  04-07-2021_09-40-41.791389
# 4      0.475000   57.00   63.0  117.00  04-07-2021_09-51-56.156181
#
#          measurement_end_time      fault_profile cluster_type  \
# 0  04-07-2021_00-14-41.240349             custom          eks
# 1  04-07-2021_00-38-58.831217  network-partition          eks
# 2  04-07-2021_00-55-12.140483  network-partition          eks
# 3  04-07-2021_09-50-48.832709                 io          eks
# 4  04-07-2021_10-02-03.017025                 io          eks
#
#    measurement_count  load_duration  locust_user_count  locust_spawn_rate  \
# 0                  1            600                  1                  1
# 1                  2            600                  1                  1
# 2                  2            600                  1                  1
# 3                 10            600                  1                  1
# 4                 10            600                  1                  1
#
#   prev_stack_git_commit_short               comment
# 0                     bf5a942        First EKS test
# 1                     3c228d6       Second EKS test
# 2                     3c228d6       Second EKS test
# 3                     caa27f7  First proper IO test
# 4                     caa27f7  First proper IO test

# %%
# results_raw.dtypes

# %%
results_avg_by_id = results_raw.groupby(by=['id']).mean()
results_avg_by_id.head()
# Out:
#                                       availability         mut         mdt  \
# id
# 66151945-dd5d-498d-8cf1-7889b2f5045b      0.942436  236.550000   17.500000
# 671d615f-b3d7-4437-9a7f-1d12c0e6b931      0.773397  169.400000   41.111111
# a1bbcd60-c96b-421b-ac9a-0d7a0c30db6c      0.473106  114.305556  182.750000
# abddcd4f-e494-4e72-9883-f78883f76d32      0.951795  307.300000   18.000000
# bc178dca-4bea-43e0-8432-d3facc3eadd2      0.300064  301.500000         inf
#
#                                             mtbf  measurement_count  \
# id
# 66151945-dd5d-498d-8cf1-7889b2f5045b  213.666667                 10
# 671d615f-b3d7-4437-9a7f-1d12c0e6b931  163.166667                 10
# a1bbcd60-c96b-421b-ac9a-0d7a0c30db6c  251.111111                 10
# abddcd4f-e494-4e72-9883-f78883f76d32  252.125000                 10
# bc178dca-4bea-43e0-8432-d3facc3eadd2         inf                 10
#
#                                       load_duration  locust_user_count  \
# id
# 66151945-dd5d-498d-8cf1-7889b2f5045b            600                  1
# 671d615f-b3d7-4437-9a7f-1d12c0e6b931            600                  1
# a1bbcd60-c96b-421b-ac9a-0d7a0c30db6c            600                  1
# abddcd4f-e494-4e72-9883-f78883f76d32            600                  1
# bc178dca-4bea-43e0-8432-d3facc3eadd2            600                  1
#
#                                       locust_spawn_rate
# id
# 66151945-dd5d-498d-8cf1-7889b2f5045b                  1
# 671d615f-b3d7-4437-9a7f-1d12c0e6b931                  1
# a1bbcd60-c96b-421b-ac9a-0d7a0c30db6c                  1
# abddcd4f-e494-4e72-9883-f78883f76d32                  1
# bc178dca-4bea-43e0-8432-d3facc3eadd2                  1

# %%
result_ids_with_other_infos = results_raw.loc[:, ['id', 'fault_profile', 'measurement_seq_start_time', 'cluster_type', 'comment']] \
    .drop_duplicates() \
    .reset_index(drop=True)
result_ids_with_other_infos
# Out:
#                                      id      fault_profile  \
# 0  d73e6687-5dde-4630-ac81-cc782cc4182c             custom
# 1  c1be61c2-580d-4b2d-8aeb-2446c1bed119  network-partition
# 2  fb02bd7c-3434-4a65-821f-e527270cee19                 io
# 3  671d615f-b3d7-4437-9a7f-1d12c0e6b931      network-delay
# 4  e99aeb09-3f6c-41c6-bcfd-8bb203e5fbc1        pod-failure
# 5  a1bbcd60-c96b-421b-ac9a-0d7a0c30db6c           pod-kill
# 6  66151945-dd5d-498d-8cf1-7889b2f5045b         stress-cpu
# 7  abddcd4f-e494-4e72-9883-f78883f76d32         stress-mem
# 8  f6331fa5-8d6c-4977-96d7-54cf0e447778               none
# 9  bc178dca-4bea-43e0-8432-d3facc3eadd2  network-partition
#
#    measurement_seq_start_time cluster_type  \
# 0  04-07-2021_00-04-20.303398          eks
# 1  04-07-2021_00-28-40.470254          eks
# 2  04-07-2021_09-40-34.423576          eks
# 3  04-07-2021_13-42-17.181397          eks
# 4  04-09-2021_19-31-57.405869          eks
# 5  04-09-2021_22-02-12.724972          eks
# 6  04-10-2021_13-46-58.258675          eks
# 7  04-10-2021_16-12-38.022300          eks
# 8  04-10-2021_19-09-48.270519          eks
# 9  04-30-2021_18-14-50.598459          eks
#
#                                comment
# 0                       First EKS test
# 1                      Second EKS test
# 2                 First proper IO test
# 3      First proper network delay test
# 4               First pod failure test
# 5                  First pod kill test
# 6                First stress CPU test
# 7             First stress memory test
# 8              First none profile test
# 9  Third proper network partition test

# %%
results_avg_all_info = pd.merge(results_avg_by_id, result_ids_with_other_infos, on='id')

# filter out measurement sequence with less than 10 measurements
results_avg_all_info = results_avg_all_info[results_avg_all_info['measurement_count'] >= 10]

results_avg_all_info
# Out:
#                                      id  availability         mut         mdt  \
# 0  66151945-dd5d-498d-8cf1-7889b2f5045b      0.942436  236.550000   17.500000
# 1  671d615f-b3d7-4437-9a7f-1d12c0e6b931      0.773397  169.400000   41.111111
# 2  a1bbcd60-c96b-421b-ac9a-0d7a0c30db6c      0.473106  114.305556  182.750000
# 3  abddcd4f-e494-4e72-9883-f78883f76d32      0.951795  307.300000   18.000000
# 4  bc178dca-4bea-43e0-8432-d3facc3eadd2      0.300064  301.500000         inf
# 7  e99aeb09-3f6c-41c6-bcfd-8bb203e5fbc1      0.213397   87.812500  272.500000
# 8  f6331fa5-8d6c-4977-96d7-54cf0e447778      0.962372  384.500000   21.666667
# 9  fb02bd7c-3434-4a65-821f-e527270cee19      0.498718   57.750000   57.650000
#
#          mtbf  measurement_count  load_duration  locust_user_count  \
# 0  213.666667                 10            600                  1
# 1  163.166667                 10            600                  1
# 2  251.111111                 10            600                  1
# 3  252.125000                 10            600                  1
# 4         inf                 10            600                  1
# 7  278.437500                 10            600                  1
# 8  414.722222                 10            600                  1
# 9  114.457143                 10            600                  1
#
#    locust_spawn_rate      fault_profile  measurement_seq_start_time  \
# 0                  1         stress-cpu  04-10-2021_13-46-58.258675
# 1                  1      network-delay  04-07-2021_13-42-17.181397
# 2                  1           pod-kill  04-09-2021_22-02-12.724972
# 3                  1         stress-mem  04-10-2021_16-12-38.022300
# 4                  1  network-partition  04-30-2021_18-14-50.598459
# 7                  1        pod-failure  04-09-2021_19-31-57.405869
# 8                  1               none  04-10-2021_19-09-48.270519
# 9                  1                 io  04-07-2021_09-40-34.423576
#
#   cluster_type                              comment
# 0          eks                First stress CPU test
# 1          eks      First proper network delay test
# 2          eks                  First pod kill test
# 3          eks             First stress memory test
# 4          eks  Third proper network partition test
# 7          eks               First pod failure test
# 8          eks              First none profile test
# 9          eks                 First proper IO test

# %%
results_avg_fault_profile_idx = results_avg_all_info.set_index(results_avg_all_info.loc[:, 'fault_profile'])
results_avg_fault_profile_idx
# Out:
#                                                      id  availability  \
# fault_profile
# stress-cpu         66151945-dd5d-498d-8cf1-7889b2f5045b      0.942436
# network-delay      671d615f-b3d7-4437-9a7f-1d12c0e6b931      0.773397
# pod-kill           a1bbcd60-c96b-421b-ac9a-0d7a0c30db6c      0.473106
# stress-mem         abddcd4f-e494-4e72-9883-f78883f76d32      0.951795
# network-partition  bc178dca-4bea-43e0-8432-d3facc3eadd2      0.300064
# pod-failure        e99aeb09-3f6c-41c6-bcfd-8bb203e5fbc1      0.213397
# none               f6331fa5-8d6c-4977-96d7-54cf0e447778      0.962372
# io                 fb02bd7c-3434-4a65-821f-e527270cee19      0.498718
#
#                           mut         mdt        mtbf  measurement_count  \
# fault_profile
# stress-cpu         236.550000   17.500000  213.666667                 10
# network-delay      169.400000   41.111111  163.166667                 10
# pod-kill           114.305556  182.750000  251.111111                 10
# stress-mem         307.300000   18.000000  252.125000                 10
# network-partition  301.500000         inf         inf                 10
# pod-failure         87.812500  272.500000  278.437500                 10
# none               384.500000   21.666667  414.722222                 10
# io                  57.750000   57.650000  114.457143                 10
#
#                    load_duration  locust_user_count  locust_spawn_rate  \
# fault_profile
# stress-cpu                   600                  1                  1
# network-delay                600                  1                  1
# pod-kill                     600                  1                  1
# stress-mem                   600                  1                  1
# network-partition            600                  1                  1
# pod-failure                  600                  1                  1
# none                         600                  1                  1
# io                           600                  1                  1
#
#                        fault_profile  measurement_seq_start_time cluster_type  \
# fault_profile
# stress-cpu                stress-cpu  04-10-2021_13-46-58.258675          eks
# network-delay          network-delay  04-07-2021_13-42-17.181397          eks
# pod-kill                    pod-kill  04-09-2021_22-02-12.724972          eks
# stress-mem                stress-mem  04-10-2021_16-12-38.022300          eks
# network-partition  network-partition  04-30-2021_18-14-50.598459          eks
# pod-failure              pod-failure  04-09-2021_19-31-57.405869          eks
# none                            none  04-10-2021_19-09-48.270519          eks
# io                                io  04-07-2021_09-40-34.423576          eks
#
#                                                comment
# fault_profile
# stress-cpu                       First stress CPU test
# network-delay          First proper network delay test
# pod-kill                           First pod kill test
# stress-mem                    First stress memory test
# network-partition  Third proper network partition test
# pod-failure                     First pod failure test
# none                           First none profile test
# io                                First proper IO test

# %%
# Availability on average per fault profiles
ax = results_avg_fault_profile_idx.loc[:, 'availability'].plot.bar(figsize=(16, 13), fontsize=18)
for p in ax.patches:
    ax.annotate('{:.3f}'.format(p.get_height()), (p.get_x() - 0.06, p.get_height() + 0.01))

# %%
# MUT, MDT, MTBF on average per fault profiles
#  .legend(prop={'size': 50}
ax = results_avg_fault_profile_idx.loc[:, ['mut', 'mdt', 'mtbf']] \
    .plot.bar(figsize=(20, 15), fontsize=18, ylabel="seconds")
for p in ax.patches:
    ax.annotate('{:.3f}'.format(p.get_height()), (p.get_x() - 0.06, p.get_height() + 5))

# %%
### All measurements where meas count is at least 10
results = results_raw[results_raw['measurement_count'] >= 10].reset_index(drop=True)
results
# Out:
#                                       id  measurement_seq_start_time  \
# 0   fb02bd7c-3434-4a65-821f-e527270cee19  04-07-2021_09-40-34.423576
# 1   fb02bd7c-3434-4a65-821f-e527270cee19  04-07-2021_09-40-34.423576
# 2   fb02bd7c-3434-4a65-821f-e527270cee19  04-07-2021_09-40-34.423576
# 3   fb02bd7c-3434-4a65-821f-e527270cee19  04-07-2021_09-40-34.423576
# 4   fb02bd7c-3434-4a65-821f-e527270cee19  04-07-2021_09-40-34.423576
# ..                                   ...                         ...
# 75  bc178dca-4bea-43e0-8432-d3facc3eadd2  04-30-2021_18-14-50.598459
# 76  bc178dca-4bea-43e0-8432-d3facc3eadd2  04-30-2021_18-14-50.598459
# 77  bc178dca-4bea-43e0-8432-d3facc3eadd2  04-30-2021_18-14-50.598459
# 78  bc178dca-4bea-43e0-8432-d3facc3eadd2  04-30-2021_18-14-50.598459
# 79  bc178dca-4bea-43e0-8432-d3facc3eadd2  04-30-2021_18-14-50.598459
#
#     availability    mut    mdt   mtbf      measurement_start_time  \
# 0       0.475000   57.0   60.0  117.0  04-07-2021_09-40-41.791389
# 1       0.475000   57.0   63.0  117.0  04-07-2021_09-51-56.156181
# 2       0.475000   57.0   63.0  120.0  04-07-2021_10-03-11.174438
# 3       0.538462   66.0   54.0  120.0  04-07-2021_10-13-59.800418
# 4       0.487179   57.0   60.0  117.0  04-07-2021_10-25-15.592725
# ..           ...    ...    ...    ...                         ...
# 75      0.000000    NaN  585.0    NaN  04-30-2021_19-09-07.583199
# 76      0.000000    NaN  585.0    NaN  04-30-2021_19-19-57.521221
# 77      1.000000  600.0    NaN    NaN  04-30-2021_19-30-15.104009
# 78      0.975000  292.5   15.0  307.5  04-30-2021_19-41-21.427405
# 79      1.000000  600.0    NaN    NaN  04-30-2021_19-52-22.525354
#
#           measurement_end_time      fault_profile cluster_type  \
# 0   04-07-2021_09-50-48.832709                 io          eks
# 1   04-07-2021_10-02-03.017025                 io          eks
# 2   04-07-2021_10-13-17.819658                 io          eks
# 3   04-07-2021_10-24-07.455792                 io          eks
# 4   04-07-2021_10-35-21.943853                 io          eks
# ..                         ...                ...          ...
# 75  04-30-2021_19-19-16.869626  network-partition          eks
# 76  04-30-2021_19-30-07.341985  network-partition          eks
# 77  04-30-2021_19-40-24.305851  network-partition          eks
# 78  04-30-2021_19-51-30.610819  network-partition          eks
# 79  04-30-2021_20-02-32.593606  network-partition          eks
#
#     measurement_count  load_duration  locust_user_count  locust_spawn_rate  \
# 0                  10            600                  1                  1
# 1                  10            600                  1                  1
# 2                  10            600                  1                  1
# 3                  10            600                  1                  1
# 4                  10            600                  1                  1
# ..                ...            ...                ...                ...
# 75                 10            600                  1                  1
# 76                 10            600                  1                  1
# 77                 10            600                  1                  1
# 78                 10            600                  1                  1
# 79                 10            600                  1                  1
#
#    prev_stack_git_commit_short                              comment
# 0                      caa27f7                 First proper IO test
# 1                      caa27f7                 First proper IO test
# 2                      caa27f7                 First proper IO test
# 3                      caa27f7                 First proper IO test
# 4                      caa27f7                 First proper IO test
# ..                         ...                                  ...
# 75                     dbbbe50  Third proper network partition test
# 76                     dbbbe50  Third proper network partition test
# 77                     dbbbe50  Third proper network partition test
# 78                     dbbbe50  Third proper network partition test
# 79                     dbbbe50  Third proper network partition test
#
# [80 rows x 16 columns]

# %%
# Availability distribution of all measurements per fault profiles
availability_all = results.loc[:, ['availability', 'fault_profile']]

availability_all.pivot(columns='fault_profile') \
    .plot.box(by='fault_profile', figsize=(20,15), fontsize=10)
# Out:
# <AxesSubplot:>
